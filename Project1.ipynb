# %% [raw]
# #Project 1
# #Explore the dataset from Kaggle, dc_properties.csv
# #Laura Menefee
# #6/27/2019

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#load dc_properties.csv into dataframe
location = 'datasets/dc_properties.csv'
df = pd.read_csv(location)
# Out:
# C:\Users\Laura\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# original row column counts      (158957, 49)
df.shape
# Out:
# (158957, 49)

# %%
#look at first 5 rows of data
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
#What are the columns?
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
#where are the null values?
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
#samething, different function. where are the na's?"
df.isna().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
#lok at numeric data
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
##  look at columns and unique values
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.BATHRM.unique()
# Out:
# array([ 4,  3,  2,  1,  5,  6,  7,  8, 11,  9,  0, 10, 12, 14, 13],
#       dtype=int64)

# %%
df.HF_BATHRM.unique()
# Out:
# array([ 0,  1,  2,  3,  4,  5,  6,  7,  9, 11], dtype=int64)

# %%
df.HEAT.unique()
# Out:
# array(['Warm Cool', 'Hot Water Rad', 'Forced Air', 'Elec Base Brd',
#        'Ht Pump', 'Electric Rad', 'Wall Furnace', 'Water Base Brd',
#        'Evp Cool', 'Air Exchng', 'No Data', 'Ind Unit', 'Gravity Furnac',
#        'Air-Oil'], dtype=object)

# %%
df.BEDRM.unique()
# Out:
# array([ 4,  5,  3,  2,  6,  7,  1,  8,  9, 10, 11,  0, 20, 12, 16, 24, 13,
#        15, 19, 14], dtype=int64)

# %%
df.PRICE.unique()   #  not very helpful
# Out:
# array([1095000.,      nan, 2100000., ...,  915500.,  908500.,  485355.])

# %%
df.STORIES.unique()
# Out:
# array([3.00e+00, 4.00e+00, 2.00e+00, 2.50e+00, 2.25e+00, 3.50e+00,
#        1.00e+00,      nan, 3.25e+00, 1.50e+00, 2.75e+00, 7.00e+00,
#        6.50e+01, 2.70e+00, 0.00e+00, 8.26e+02, 6.00e+00, 2.30e+00,
#        5.00e+00, 2.20e+00, 3.70e+00, 1.70e+00, 3.20e+00, 1.75e+00,
#        3.75e+00, 4.50e+00, 2.50e+02, 2.75e+02, 1.25e+00, 2.50e+01,
#        4.75e+00, 9.00e+00, 5.00e-01, 8.25e+00, 7.50e-01, 2.33e+00,
#        2.00e+01, 1.20e+01, 4.30e+01, 1.34e+00, 2.50e-01])

# %%
df.CITY.unique()
# Out:
# array(['WASHINGTON', nan], dtype=object)

# %%
df['WARD'].unique()
# Out:
# array(['Ward 2', 'Ward 1', 'Ward 6', 'Ward 5', 'Ward 3', 'Ward 4',
#        'Ward 7', 'Ward 8', nan], dtype=object)

# %%
df.QUADRANT.unique()
# Out:
# array(['NW', 'SW', 'SE', 'NE', nan], dtype=object)

# %%
#any total missin values
dupe = df.duplicated()
df.loc[dupe]

# No
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
#df.PRICE
len(df)
# Out:
# 158957

# %%
# look at rows that have null PRICE

#df.loc[df['PRICE'] > 0]     #98216

#df.loc[df['PRICE'].isnull()    #60741
 

nullprice=df['PRICE'].isnull()
df.loc[nullprice]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 1                1       3          1      Warm Cool  Y        2.0     11
# 4                4       2          1      Warm Cool  Y        1.0     11
# 6                6       1          0      Warm Cool  Y        2.0      5
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# 12              12       2          0  Hot Water Rad  N        2.0      9
# 13              13       2          0      Warm Cool  Y        2.0     11
# 15              15       2          1      Warm Cool  Y        2.0      9
# 17              17       2          0  Hot Water Rad  N        1.0      6
# 18              18       3          1  Hot Water Rad  Y        2.0     10
# 21              21       3          0     Forced Air  Y        2.0     12
# ...

# %%
#look at the data
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
#what is orginal rows & columns?
df.shape
# Out:
# (158957, 49)

# %%
# Delete column from dataframe that are not needed now, not interested in location gis data
#  Also, looked at data in exce by importing csv file.... pain writing python code !!  :-)
# 'NATIONALGRID','LATITUDE', 'LONGITUDE',  'X', 'Y',''

#df.drop?
#df.shape   #(158957, 49)

#df.drop(['NATIONALGRID','LATITUDE', 'LONGITUDE',  'X', 'Y'], axis=1, inplace=True)

#df.shape  #(158957, 44)  num of rows now 44!

df.columns   #  dropped columns not in column list
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE',
#        'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD', 'CENSUS_TRACT', 'CENSUS_BLOCK',
#        'WARD', 'SQUARE', 'QUADRANT'],
#       dtype='object')

# %%
# mean price by num of bedrooms

df['PRICE'].groupby(df['BEDRM']).mean()
# Out:
# BEDRM
# 0     1.992876e+06
# 1     1.927088e+06
# 2     6.482021e+05
# 3     4.821091e+05
# 4     6.659285e+05
# 5     1.042489e+06
# 6     1.266913e+06
# 7     1.721509e+06
# 8     8.107116e+05
# 9     2.718745e+06
# 10    6.924450e+05
# 11    1.025980e+06
# 12    1.547980e+06
# 13    4.425000e+05
# 14    9.250000e+05
# 15    1.105000e+06
# 16             NaN
# 19             NaN
# 20    1.900000e+06
# 24             NaN
# Name: PRICE, dtype: float64

# %%
#mean price by city quadrant
df['PRICE'].groupby(df['QUADRANT']).mean()
# Out:
# QUADRANT
# NE    3.928715e+05
# NW    1.317785e+06
# SE    3.682260e+05
# SW    3.470489e+05
# Name: PRICE, dtype: float64

# %%
#create pivot table --mean value
pd.pivot_table(df, values=['PRICE'],index=['BEDRM','BATHRM'])
# Out:
#                      PRICE
# BEDRM BATHRM
# 0     0       2.602079e+06
#       1       1.989367e+06
#       2       5.677480e+05
#       3       2.040500e+05
#       4       6.715590e+06
# 1     0       2.860000e+05
#       1       1.887415e+06
#       2       2.753084e+06
#       3       6.520667e+05
#       4       2.539750e+05
# 2     0       6.894500e+05
#       1       4.706987e+05
#       2       7.829985e+05
#       3       7.162117e+05
#       4       8.532768e+05
# 3     0       4.225000e+05
#       1       3.094116e+05
#       2       5.031922e+05
#       3       7.185585e+05
#       4       1.013861e+06
#       5       2.219800e+06
#       6       4.000000e+05
#       7       4.217000e+06
# 4     0       8.500000e+05
#       1       3.397873e+05
#       2       5.151250e+05
#       3       7.792648e+05
#       4       7.937731e+05
#       5       1.825532e+06
#       6       2.264856e+06
# ...                    ...
# 9     3       5.789950e+05
# ...

# %%
#look at year built , price

#create pivot table --mean value
pd.pivot_table(df, values=['PRICE'],index=['AYB'])
# Out:
#                PRICE
# AYB
# 1754.0  7.100000e+06
# 1765.0  1.100000e+06
# 1776.0  4.742500e+05
# 1780.0  7.716667e+05
# 1790.0  1.512167e+06
# 1794.0  3.400000e+06
# 1796.0  3.640000e+06
# 1800.0  8.021075e+05
# 1801.0  9.063000e+06
# 1802.0  1.812500e+06
# 1803.0  9.100000e+05
# 1805.0  8.533057e+06
# 1807.0  3.075000e+06
# 1810.0  2.308750e+06
# 1811.0  3.175000e+06
# 1812.0  4.945000e+05
# 1813.0  2.063750e+06
# 1815.0  2.147814e+06
# 1816.0  3.611250e+06
# 1818.0  1.015127e+06
# 1819.0  1.112500e+06
# 1820.0  2.264750e+06
# 1822.0  8.290000e+05
# 1825.0  1.640000e+06
# 1830.0  9.848625e+05
# 1833.0  6.350000e+05
# 1834.0  9.170000e+05
# 1835.0  6.500000e+05
# 1840.0  1.195769e+06
# 1842.0  3.050000e+05
# ...              ...
# 1989.0  2.064534e+07
# 1990.0  6.397416e+05
# 1991.0  4.627884e+05
# 1992.0  8.326606e+05
# 1993.0  7.609145e+05
# 1994.0  6.190759e+05
# 1995.0  7.476852e+05
# 1996.0  8.773640e+05
# 1997.0  4.788404e+05
# 1998.0  6.088357e+05
# 1999.0  5.590457e+05
# ...

# %%
#look at year built , number of bedrooms

#create pivot table --mean value
pd.pivot_table(df, values=['BEDRM'],index=['AYB'])
# Out:
#            BEDRM
# AYB
# 1754.0  6.500000
# 1765.0  2.000000
# 1776.0  3.333333
# 1780.0  2.000000
# 1782.0  3.000000
# 1784.0  4.000000
# 1785.0  2.000000
# 1787.0  8.000000
# 1788.0  4.000000
# 1790.0  3.666667
# 1791.0  4.000000
# 1793.0  4.000000
# 1794.0  4.000000
# 1795.0  6.000000
# 1796.0  4.500000
# 1797.0  9.000000
# 1799.0  5.000000
# 1800.0  2.318182
# 1801.0  5.250000
# 1802.0  3.500000
# 1803.0  2.500000
# 1805.0  6.111111
# 1806.0  2.000000
# 1807.0  5.000000
# 1808.0  3.000000
# 1810.0  4.000000
# 1811.0  3.500000
# 1812.0  2.666667
# 1813.0  2.500000
# 1815.0  3.222222
# ...          ...
# 1990.0  2.545775
# 1991.0  1.737179
# 1992.0  3.741935
# 1993.0  3.902439
# 1994.0  3.319820
# 1995.0  3.134615
# 1996.0  3.384058
# 1997.0  3.006024
# 1998.0  2.137584
# 1999.0  2.965079
# 2000.0  2.488304
# 2001.0  3.101083
# 2002.0  2.171737
# 2003.0  2.047546
# 2004.0  1.675460
# 2005.0  1.623486
# 2006.0  1.729074
# 2007.0  1.927543
# 2008.0  2.151386
# 2009.0  2.297940
# ...
